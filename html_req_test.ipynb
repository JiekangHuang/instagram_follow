# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
datas = pd.read_csv('IG_user.csv')

# %%
for data in datas['user']:
    print(data)
# Out:
# a23890777
# a23890988
# jolin910202
# sinny_g20002019
# love.love.love.88
# z1234577777
# cytherea0925
# happy801991
# tantan199101
# b.t.s.jimin.jk
# 4.ever.4.ever
# ray.girl945
# sinny_gz000
# jo.jo.520

# %%
datas['user']
# Out:
# 0             a23890777
# 1             a23890988
# 2           jolin910202
# 3       sinny_g20002019
# 4     love.love.love.88
# 5           z1234577777
# 6          cytherea0925
# 7           happy801991
# 8          tantan199101
# 9        b.t.s.jimin.jk
# 10        4.ever.4.ever
# 11          ray.girl945
# 12          sinny_gz000
# 13            jo.jo.520
# Name: user, dtype: object

# %%
url = 'https://www.instagram.com/accounts/login/?source=auth_switcher'
html = requests.get(url).text.encode('utf-8-sig')

# %%
headers = {
'Host': 'www.instagram.com',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0',
'Accept': '*/*',
'Accept-Language': 'zh-TW,zh;q=0.8,en-US;q=0.5,en;q=0.3',
'Accept-Encoding': 'gzip, deflate, br',
'X-CSRFToken': 'RxnscwY85iJUoEwZJJOpxQV27F43N5W9',
'X-IG-App-ID': '936619743392459',
'X-IG-WWW-Claim': '0',
#'Content-Type': 'application/x-www-form-urlencoded',
#'X-Requested-With': 'XMLHttpRequest',
#'Content-Length': '2332',
#'Origin': 'https://www.instagram.com',
#'Connection': 'keep-alive',
#'Referer': 'https://www.instagram.com/accounts/login/?source=auth_switcher',
#'Cookie': 'ig_did=E59BB4ED-E530-4411-B9CA-43A9943C3E17; csrftoken=RxnscwY85iJUoEwZJJOpxQV27F43N5W9; rur=FRC; mid=XjlzbAALAAH6_ds0-h15iNqMS-wd',
#'TE': 'Trailers'
}
    
USERNAME = ""
PASSWORD = ""
LOGIN_URL = 'https://www.instagram.com/accounts/login'

session_requests = requests.session()
result = session_requests.get(LOGIN_URL, headers=headers)
result.request.headers
# Out:
# {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive', 'Host': 'www.instagram.com', 'Accept-Language': 'zh-TW,zh;q=0.8,en-US;q=0.5,en;q=0.3', 'X-CSRFToken': 'RxnscwY85iJUoEwZJJOpxQV27F43N5W9', 'X-IG-App-ID': '936619743392459', 'X-IG-WWW-Claim': '0', 'Cookie': 'ig_did=329E0A00-E7C4-4B62-9C04-9E28F9197ED9; rur=FRC'}

# %%
sp = BeautifulSoup(result.text,'html.parser')
sp
# Out:
# <!DOCTYPE html>
#
# <html class="no-js not-logged-in client-root" lang="zh-tw">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>
# 登入 • Instagram
# </title>
# <meta content="noimageindex, noarchive" name="robots"/>
# <meta content="default" name="apple-mobile-web-app-status-bar-style"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1, viewport-fit=cover" id="viewport" name="viewport"/>
# <link href="/data/manifest.json" rel="manifest"/>
# <link as="style" crossorigin="anonymous" href="/static/bundles/es6/ConsumerUICommons.css/d1e3d67871d3.css" rel="preload" type="text/css">
# <link as="style" crossorigin="anonymous" href="/static/bundles/es6/ConsumerAsyncCommons.css/3c0ec6f379e9.css" rel="preload" type="text/css"/>
# ...
